# %% [markdown]
# # Data cleaning
#
# ## Importations

# %%
import json
import pandas as pd
import re
from nltk.tokenize import TweetTokenizer
import string
import nltk.corpus
# nltk.download('stopwords')

# %% [markdown]
# ## Function definition

# %%
def non_ascii(s):
    return "".join(i for i in s if ord(i)<128)

def clean_links(text):
    txt = re.compile('http(s)?://\w+(\.\w+){1,}(/\w+)*')
    return txt.sub(r'', str(text))

def clean_html(text):
    html = re.compile('<.*?>|&[A-Za-z0-9_]+')
    return html.sub(r'', str(text))

def remove_twitter_entities(text): # Hashtags, urls and usernames
    return ' '.join(re.sub("(#[A-Za-z0-9]+)|(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",str(text)).split())

def clean_web(text):
    text = clean_links(text)
    text = clean_html(text)
    return text

def punct(text):
    token = nltk.tokenize.RegexpTokenizer(r'\w+')
    text = token.tokenize(text)
    text = " ".join(text)
    return text

def clean(text):
    text = non_ascii(text)
    text = str.lower(text)
    text = clean_links(text)
    text = clean_html(text)
    text = punct(text)
    return text

# %% [markdown]
# ## Tweets
#
# We want to clean the text from each tweet obtained. That means, removing special characters of any kind and only keeping the relevant words for the analysis.
#
# ### Data importation
#
# First of all, we will need to import the tweets recolected.

# %%
# Define companies' names and its products names
entities = ['Nintendo', 'Playstation', 'Xbox', 'Engage', 'Forspoken', 'HFRush']

# %%
entities
# Out:
# ['Nintendo', 'Playstation', 'Xbox', 'Engage', 'Forspoken', 'HFRush']

# %%
# Import tweets
tweets = {}
for entity in entities:
    path = f'Videojocs/tweets/{entity}.json'
    with open(path) as json_file:
        data = json.load(json_file)
        tweets[entity] = pd.DataFrame(data['data'])
        tweets[entity] = tweets[entity].loc[:, ['text']] # We only keep text column, since is what we are interested in

# %% [markdown]
# ### Data cleaning
#
# Our first mission is to clean the text from all unwanted characters or information. This mean urls, non ascii characters, punctuation signs and even html components. We will do that thanks to the **clean** function defined at the beginning of the notebook.

# %%
# Data cleaning
for entity in entities:
    tweets[entity]['cleanText'] = tweets[entity]['text'].apply(clean_web)
    tweets[entity]['cleanText'] = tweets[entity]['cleanText'].apply(remove_twitter_entities)
    tweets[entity]['cleanText'] = tweets[entity]['cleanText'].apply(str.lower)

# %% [markdown]
# ### Tokenization
# Once we have imported all the required data, we will first perform the process known as **text tokenization**. This consists on splitting the text into tokens in order to identify the different topics which are discussed in the text.

# %%
for entity in entities:
    tweets[entity]['tokens'] = tweets[entity]['cleanText'].apply(TweetTokenizer().tokenize)

# %% [markdown]
# ### Stop words
#
# After splitting the text into different tokens, the next step is to remove the so called **stop words**, which are words that do not have any kind of relevant meaning and are just used to link semantical words.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopwords_vocabulary = stopwords.words('english')
for entity in entities:
    tweets[entity]['final'] = tweets[entity]['tokens'].apply(lambda x: [i for i in x if i.lower() not in stopwords_vocabulary])
    tweets[entity]['final'] = tweets[entity]['final'].apply(lambda x: [i for i in x if i.lower() not in list(string.punctuation)])
    tweets[entity]['final'] = tweets[entity]['final'].apply(lambda x: [i for i in x if i.lower() not in list(string.digits)])
    tweets[entity]['final'] = tweets[entity]['final'].apply(lambda x: [i for i in x if len(i) > 1]) # Remove single characters
    tweets[entity]['finalText'] = [' '.join(map(str, token)) for token in tweets[entity]['final']]

# %% [markdown]
# ### Stemming and lemmatization
#
# Lastly, we want to obtain the ulterior meaning behind every word, which can be retrieved if we just keep the stem of each word. This process can be done in an easy way called **stemming** (reducing inflected or sometimes derived words to their word stem, base or root form), or in a more complex way called **lemmatization** (group together inflected forms of a word so they can be analysed as a single item, identified by the word's lemma/dictionary form).
#
# The difference between stemming and lemmatization is that lemmatization considers the context and converts the word to its meaningful base form, whereas stemming just removes the last few characters, often leading to incorrect meanings and spelling errors.

# %%
# STEMMING
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer('english')
for entity in entities:
    tweets[entity]['stemmed'] = tweets[entity]['final'].apply(lambda x: [stemmer.stem(y) for y in x])
    tweets[entity]['stemmedText'] = [' '.join(map(str, token)) for token in tweets[entity]['stemmed']]

# %%
# LEMMATIZATION
#import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
wnl = WordNetLemmatizer()
for entity in entities:
    tweets[entity]['lemmatized'] = tweets[entity]['final'].apply(lambda x: [wnl.lemmatize(y) for y in x])
    tweets[entity]['lemmatizedText'] = [' '.join(map(str, token)) for token in tweets[entity]['lemmatized']]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\barri\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\barri\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
#print(tweets['Nintendo']['tokens'])
tweets['Nintendo']
# Out:
#                                                     text  \
# 0      Good guy Nintendo. Gotta give credit where it'...
# 1      Finally caved &amp; got myself a Nintendo Swit...
# 2      PXN V3 Pro Gaming Racing Wheel Volante PC Stee...
# 3      Nintendo Will Pay Its Workers 10% More https:/...
# 4      Nintendo seeing Tomodachi Life trending on twi...
# ...                                                  ...
# 36831  #NintendoNetwork #NintendoNetworkDown\n https:...
# 36832  Mega Man X2 Super Nintendo SNES Video Game Lot...
# 36833  February means we are definitely on official N...
# 36834  Get pre order bonus for Kirby returns to dream...
# 36835  Live in 15 with Kirby 64: I may have gotten th...
#
#                                                cleanText  \
# 0      good guy nintendo gotta give credit where it s...
# 1      finally caved got myself a nintendo switch i m...
# 2      pxn v3 pro gaming racing wheel volante pc stee...
# 3               nintendo will pay its workers 10 more 11
# 4      nintendo seeing tomodachi life trending on twi...
# ...                                                  ...
# 36831  nintendo network down 1 31 2023 why nintendo n...
# 36832  mega man x2 super nintendo snes video game lot...
# 36833  february means we are definitely on official n...
# 36834  get pre order bonus for kirby returns to dream...
# 36835  live in 15 with kirby 64 i may have gotten the...
#
#                                                finalText  \
# 0      good guy nintendo gotta give credit due everyo...
# 1      finally caved got nintendo switch healing inne...
# 2      pxn v3 pro gaming racing wheel volante pc stee...
# 3                             nintendo pay workers 10 11
# 4        nintendo seeing tomodachi life trending twitter
# ...                                                  ...
# 36831  nintendo network 31 2023 nintendo network work...
# 36832  mega man x2 super nintendo snes video game lot...
# 36833  february means definitely official nintendo di...
# 36834  get pre order bonus kirby returns dream land d...
# 36835  live 15 kirby 64 may gotten shards still leave...
#
#                                              stemmedText  \
# 0      good guy nintendo gotta give credit due everyo...
# 1      final cave got nintendo switch heal inner chil...
# 2      pxn v3 pro game race wheel volant pc steer whe...
# 3                              nintendo pay worker 10 11
# 4              nintendo see tomodachi life trend twitter
# ...                                                  ...
# 36831  nintendo network 31 2023 nintendo network work...
# 36832  mega man x2 super nintendo snes video game lot...
# 36833  februari mean definit offici nintendo direct w...
# 36834  get pre order bonus kirbi return dream land de...
# 36835  live 15 kirbi 64 may gotten shard still leav c...
#
#                                           lemmatizedText
# 0      good guy nintendo gotta give credit due everyo...
# 1      finally caved got nintendo switch healing inne...
# 2      pxn v3 pro gaming racing wheel volante pc stee...
# 3                              nintendo pay worker 10 11
# 4        nintendo seeing tomodachi life trending twitter
# ...                                                  ...
# 36831  nintendo network 31 2023 nintendo network work...
# 36832  mega man x2 super nintendo snes video game lot...
# 36833  february mean definitely official nintendo dir...
# 36834  get pre order bonus kirby return dream land de...
# 36835  live 15 kirby 64 may gotten shard still leaf c...
#
# [36836 rows x 5 columns]

# %%
# Errors due to stemming
print('Text clean and tokenized: ',tweets['Nintendo'].finalText[36833])
print('Stemmed text: ',tweets['Nintendo'].stemmedText[36833])
print('Lemmatized text: ',tweets['Nintendo'].lemmatizedText[36833])
# Out:
# Text clean and tokenized:  february means definitely official nintendo direct watch 2019 february 13th 2020 march 26th 2021 february 17th 2022 february 9th nothing ever 100 guaranteed odds good
# Stemmed text:  februari mean definit offici nintendo direct watch 2019 februari 13th 2020 march 26th 2021 februari 17th 2022 februari 9th noth ever 100 guarante odd good
# Lemmatized text:  february mean definitely official nintendo direct watch 2019 february 13th 2020 march 26th 2021 february 17th 2022 february 9th nothing ever 100 guaranteed odds good

# %% [markdown]
# ### Data storage
#
# Once we have cleaned the data, we will store it in order to use it in the future. We will drop the columns that does not store the text as a unique string, since we can recover them just by stripping the related columns.

# %%
for entity in entities:
    tweets[entity] = tweets[entity].drop(['tokens', 'final', 'stemmed', 'lemmatized'], axis=1)

# %%
for entity in entities:
    path = f'Videojocs/cleanTweets/{entity}.csv'
    tweets[entity].to_csv(path, index=False)

# %% [markdown]
# ## Reviews
#
# We want to clean the reviews obtained from the Metacritic web, so we just need to perform the same steps as for the cleaning done with the tweets, besides an additional language filter.
#
# ### Data importation
#
# First of all, we will need to import the data recolected.

# %%
# Define games and platforms
games = [
    {'title': 'fire-emblem-engage', 'platform': 'switch', 'name': 'feSwitch'},
    {'title': 'hi-fi-rush', 'platform': 'xbox-series-x', 'name': 'hfrushXbox'},
    {'title': 'forspoken', 'platform': 'playstation-5', 'name': 'forspokenPS5'},
    {'title': 'hi-fi-rush', 'platform': 'pc', 'name': 'hfrushPc'},
    {'title': 'forspoken', 'platform': 'pc', 'name': 'forspokenPc'}
]

# %%
# Import reviews
reviews = {}
reviewTypes = ['user', 'scored', 'unscored']
for tipo in reviewTypes:
    reviews[tipo] = {}
for game in games:
    reviews['user'][game["name"]] = pd.read_csv(f'data/userReviews/{game["title"]}_{game["platform"]}.csv')
    reviews['scored'][game["name"]] = pd.read_csv(f'data/criticReviews/scored/{game["title"]}_{game["platform"]}.csv')
    reviews['unscored'][game["name"]] = pd.read_csv(f'data/criticReviews/scored/{game["title"]}_{game["platform"]}.csv')

# %%
reviews['user']['hfrushXbox']['text'].apply(clean_web)
# Out:
# 0       Amazing Game, one of the best surprises ever! ...
# 1       It's highly recommended and one of the best vi...
# 2       Jogo perfeito! Sua jogabilidade, gráficos e hi...
# 3       The good:\rAn interesting mix of Sunset Overdr...
# 4       Başında oturdun mu saatlerce kalkamıyorsun. Yı...
#                               ...
# 1419    Love it. Great gameplay. Incredibly immersive....
# 1420    Worst game, the worst game in my entre life pl...
# 1421    This game lives up to the hype. The world conc...
# 1422                      我歌唱火焰，在我的眼睛周围，他们永远不会害怕，就像敌人奔向太阳
# 1423    Amazing game! I loved the art style, all plent...
# Name: text, Length: 1424, dtype: object

# %% [markdown]
# ### Data cleaning
#
# Our firts mission is to clean the text from all unwanted characters or information. This mean urls, non ascii characters, punctuation signs and even html components. We will do that thanks to the **clean** function defined at the beginning of the notebook.

# %%
# Data cleaning
for game in games:
    for tipo in reviewTypes:
        reviews[tipo][game["name"]]['cleanText'] = reviews[tipo][game["name"]]['text'].apply(clean_web)
        reviews[tipo][game["name"]]['cleanText'] = reviews[tipo][game["name"]]['cleanText'].apply(remove_twitter_entities)
        reviews[tipo][game["name"]]['cleanText'] = reviews[tipo][game["name"]]['cleanText'].apply(str.lower)

# %% [markdown]
# ### Language filtering
#
# As we said in the previous notebook, we must filter all the **user's reviews** that are not written in English, since they would just add noise to our tests.

# %%
from langdetect import detect

for game in games:
    reviewsToDrop = []
    for index, review in reviews['user'][game["name"]].iterrows():
        if (re.search('[a-zA-Z]', review['cleanText'])):
            if (detect(review['cleanText']) != "en"):
                #print(detect(review['cleanText']))
                reviewsToDrop.append(index)
            #print(index)
        else: # There is no text to analyze
            reviewsToDrop.append(index)
    reviews['user'][game["name"]] = reviews['user'][game["name"]].drop(reviewsToDrop)

# %% [markdown]
# ### Tokenization
# Once we have imported all the required data, we will first perform the process known as **text tokenization**. This consists on splitting the text into tokens in order to identify the different topics which are discussed in the text.

# %%
for game in games:
    for tipo in reviewTypes:
        reviews[tipo][game["name"]]['tokens'] = reviews[tipo][game["name"]]['cleanText'].apply(TweetTokenizer().tokenize)

# %% [markdown]
# ### Stop words
#
# After splitting the text into different tokens, the next step is to remove the so called **stop words**, which are words that do not have any kind of relevant meaning and are just used to link semantical words.

# %%
stopwords_vocabulary = stopwords.words('english')
for game in games:
    for tipo in reviewTypes:
        reviews[tipo][game["name"]]['final'] = reviews[tipo][game["name"]]['tokens'].apply(lambda x: [i for i in x if i.lower() not in stopwords_vocabulary])
        reviews[tipo][game["name"]]['final'] = reviews[tipo][game["name"]]['final'].apply(lambda x: [i for i in x if i.lower() not in list(string.punctuation)])
        reviews[tipo][game["name"]]['final'] = reviews[tipo][game["name"]]['final'].apply(lambda x: [i for i in x if i.lower() not in list(string.digits)])
        reviews[tipo][game["name"]]['final'] = reviews[tipo][game["name"]]['final'].apply(lambda x: [i for i in x if len(i) > 1]) # Remove single characters
        reviews[tipo][game["name"]]['finalText'] = [' '.join(map(str, token)) for token in reviews[tipo][game["name"]]['final']]

# %% [markdown]
# ### Stemming and lemmatization
#
# Lastly, we want to obtain the ulterior meaning behind every word, which can be retrieved if we just keep the stem of each word. This process can be done in an easy way called **stemming** (reducing inflected or sometimes derived words to their word stem, base or root form), or in a more complex way called **lemmatization** (group together inflected forms of a word so they can be analysed as a single item, identified by the word's lemma/dictionary form).
#
# The difference between stemming and lemmatization is that lemmatization considers the context and converts the word to its meaningful base form, whereas stemming just removes the last few characters, often leading to incorrect meanings and spelling errors.

# %%
# STEMMING
stemmer = SnowballStemmer('english')
for game in games:
    for tipo in reviewTypes:
        reviews[tipo][game["name"]]['stemmed'] = reviews[tipo][game["name"]]['final'].apply(lambda x: [stemmer.stem(y) for y in x])
        reviews[tipo][game["name"]]['stemmedText'] = [' '.join(map(str, token)) for token in reviews[tipo][game["name"]]['stemmed']]

# %%
# LEMMATIZATION
wnl = WordNetLemmatizer()
for game in games:
    for tipo in reviewTypes:
        reviews[tipo][game["name"]]['lemmatized'] = reviews[tipo][game["name"]]['final'].apply(lambda x: [wnl.lemmatize(y) for y in x])
        reviews[tipo][game["name"]]['lemmatizedText'] = [' '.join(map(str, token)) for token in reviews[tipo][game["name"]]['lemmatized']]

# %%
reviews['unscored']['hfrushXbox']
# Out:
#                         source  \
# 0               Hardcore Gamer
# 1                   TheXboxHub
# 2                    IGN Japan
# 3                   XboxAddict
# 4              Generación Xbox
# 5                 Gaming Nexus
# 6                   CGMagazine
# 7                God is a Geek
# 8                          MGG
# 9                       Forbes
# 10                     XboxEra
# 11                   SomosXbox
# 12                     GGRecon
# 13                   MondoXbox
# 14                  BaziCenter
# 15                   Shacknews
# 16                   CD-Action
# 17                TheSixthAxis
# 18                  GameSkinny
# 19             Windows Central
# 20                      Atomix
# 21                    GamersRD
# 22                    GameSpot
# 23                 SpazioGames
# 24                      Vandal
# 25                     LevelUp
# 26                     GameMAG
# 27                 The Loadout
# 28                  GamingBolt
# 29                   IGN Spain
# 30              Gamereactor UK
# 31           Xbox Achievements
# 32                 Everyeye.it
# 33              Digital Trends
# 34                 Meristation
# 35                   Pure Xbox
# 36              Hobby Consolas
# 37                  IGN Italia
# 38              Digital Chumps
# 39                   SECTOR.sk
# 40               Jeuxvideo.com
# 41              Multiplayer.it
# 42                But Why Tho?
# 43  GLHF on Sports Illustrated
# 44                    Guardian
# 45                   The Enemy
# 46            New Game Network
# 47                 GamesRadar+
# 48                 Screen Rant
# 49           Metro GameCentral
# 50                         VGC
# 51                 Destructoid
# 52               Edge Magazine
# 53                  IGN France
#
#                                                  link          date  grade  \
# 0   https://hardcoregamer.com/reviews/review-hi-fi...  Feb  1, 2023    100
# 1       https://www.thexboxhub.com/hi-fi-rush-review/  Jan 30, 2023    100
# 2   https://jp.ign.com/hi-fi-rush/65432/review/hi-...  Jan 30, 2023    100
# 3   https://www.xboxaddict.com/Staff-Review/14804/...  Feb 21, 2023     96
# 4   https://generacionxbox.com/analisis-de-hi-fi-r...  Jan 30, 2023     96
# 5   https://www.gamingnexus.com/Article/10785/Hi-F...  Feb 24, 2023     95
# 6   https://www.cgmagonline.com/review/game/hi-fi-...  Feb  7, 2023     95
# 7   https://www.godisageek.com/reviews/hi-fi-rush-...  Jan 30, 2023     95
# 8          https://www.millenium.org/test/399588.html  Jan 29, 2023     95
# 9   https://www.forbes.com/sites/paultassi/2023/01...  Jan 28, 2023     95
# 10  https://xboxera.com/2023/01/26/review-hi-fi-rush/  Jan 26, 2023     95
# 11  https://www.somosxbox.com/analisis-de-hi-fi-ru...  Jan 31, 2023     92
# 12  https://www.ggrecon.com/reviews/hi-fi-rush-rev...  Feb 25, 2023     90
# 13  https://www.mondoxbox.com/recensione/3547/hi-f...  Feb 18, 2023     90
# 14  https://www.bazicenter.com/review/game/hi-fi-r...  Feb 12, 2023     90
# 15  https://www.shacknews.com/article/134104/hi-fi...  Feb  9, 2023     90
# 16  https://cdaction.pl/recenzje/recenzja-hi-fi-ru...  Feb  7, 2023     90
# 17  https://www.thesixthaxis.com/2023/02/05/hi-fi-...  Feb  5, 2023     90
# 18  https://www.gameskinny.com/w6vy7/hi-fi-rush-re...  Feb  4, 2023     90
# 19  https://www.windowscentral.com/gaming/hi-fi-ru...  Feb  3, 2023     90
# 20               https://atomix.vg/review-hi-fi-rush/  Feb  2, 2023     90
# 21            https://gamersrd.com/hi-fi-rush-review/  Feb  1, 2023     90
# 22  https://www.gamespot.com/reviews/hi-fi-rush-re...  Feb  1, 2023     90
# 23  https://www.spaziogames.it/hi-fi-rush-recensione/  Feb  1, 2023     90
# 24  https://vandal.elespanol.com/analisis/xsx/hifi...  Jan 31, 2023     90
# 25  https://www.levelup.com/Xbox-Series-XS/juegos/...  Jan 31, 2023     90
# 26       https://gamemag.ru/reviews/hi-fi-rush-review  Jan 31, 2023     90
# 27  https://www.theloadout.com/hi-fi-rush/review-xbox  Jan 31, 2023     90
# 28  https://gamingbolt.com/hi-fi-rush-review-just-...  Jan 31, 2023     90
# 29  https://es.ign.com/hi-fi-rush/187565/review/an...  Jan 30, 2023     90
# 30      https://www.gamereactor.eu/hifi-rush-1237323/  Jan 30, 2023     90
# 31  https://www.xboxachievements.com/game/hi-fi-ru...  Jan 30, 2023     90
# 32  https://www.everyeye.it/articoli/recensione-hi...  Jan 30, 2023     90
# 33  https://www.digitaltrends.com/gaming/hi-fi-rus...  Jan 30, 2023     90
# 34  https://as.com/meristation/analisis/hi-fi-rush...  Jan 30, 2023     90
# 35  https://www.purexbox.com/reviews/xbox-series-x...  Jan 30, 2023     90
# 36  https://www.hobbyconsolas.com/reviews/analisis...  Jan 28, 2023     90
# 37  https://it.ign.com/hi-fi-rush/200091/review/hi...  Jan 30, 2023     86
# 38       https://digitalchumps.com/hi-fi-rush-review/  Feb  3, 2023     85
# 39  https://www.sector.sk/recenzia/38529/hi-fi-rus...  Jan 31, 2023     85
# 40  https://www.jeuxvideo.com/test/1702173/hi-fi-r...  Jan 30, 2023     85
# 41  https://multiplayer.it/recensioni/hi-fi-rush-r...  Jan 30, 2023     85
# 42   https://butwhytho.net/2023/01/hi-fi-rush-review/  Jan 28, 2023     85
# 43  https://videogames.si.com/reviews/hi-fi-rush-r...  Mar  9, 2023     80
# 44  https://www.theguardian.com/games/2023/feb/04/...  Feb  4, 2023     80
# 45  https://www.theenemy.com.br/xbox/criticas/revi...  Feb  3, 2023     80
# 46  https://www.newgamenetwork.com/article/2632/hi...  Jan 31, 2023     80
# 47      https://www.gamesradar.com/hi-fi-rush-review/  Jan 31, 2023     80
# 48     https://screenrant.com/hi-fi-rush-game-review/  Jan 30, 2023     80
# 49  https://metro.co.uk/2023/01/30/hi-fi-rush-revi...  Jan 29, 2023     80
# 50  https://www.videogameschronicle.com/review/hi-...  Jan 27, 2023     80
# 51  https://www.destructoid.com/reviews/review-hi-...  Feb 26, 2023     70
# 52                                                NaN  Feb 23, 2023     70
# 53  https://fr.ign.com/hi-fi-rush/63449/review/tes...  Feb  3, 2023     70
#
#    scoreType                                               text  \
# 0   Positive  \n                                What likely ...
# 1   Positive  \n                                It combines ...
# 2   Positive  \n                                Hi-Fi Rush i...
# 3   Positive  \n                                I had a smil...
# 4   Positive  \n                                There is not...
# 5   Positive  \n                                Hi-Fi Rush i...
# 6   Positive  \n                                Hi-Fi RUSH i...
# 7   Positive  \n                                Hi-Fi Rush i...
# 8   Positive  \n                                It's been a ...
# 9   Positive  \n                                Hi-Fi Rush i...
# 10  Positive  \n                                Hi-Fi RUSH c...
# 11  Positive  \n                                This is an i...
# 12  Positive  \n                                Everything c...
# 13  Positive  \n                                Hi-Fi RUSH n...
# 14  Positive  \n                                After a lack...
# 15  Positive  \n                                Hi-Fi Rush d...
# 16  Positive  \n                                Hi-Fi Rush i...
# 17  Positive  \n                                Hi-Fi Rush i...
# 18  Positive  \n                                I can't imag...
# 19  Positive  \n                                From beginni...
# 20  Positive  \n                                Tango Gamewo...
# 21  Positive  \n                                Hi-Fi Rush w...
# 22  Positive  \n                                Despite thes...
# 23  Positive  \n                                Hi-Fi Rush i...
# 24  Positive  \n                                Best of all,...
# 25  Positive  \n                                Hi-Fi RUSH i...
# 26  Positive  \n                                Hi-Fi Rush i...
# 27  Positive  \n                                Hi-Fi Rush i...
# 28  Positive  \n                                Even though ...
# 29  Positive  \n                                Hi Fi Rush i...
# 30  Positive  \n                                I simply hav...
# 31  Positive  \n                                Tango Gamewo...
# 32  Positive  \n                                Hi-Fi Rush i...
# 33  Positive  \n                                Hi-Fi Rush c...
# 34  Positive  \n                                Hi-Fi Rush i...
# 35  Positive  \n                                There's an i...
# 36  Positive  \n                                Hi-Fi Rush m...
# 37  Positive  \n                                Hi-Fi Rush i...
# 38  Positive  \n                                Hi-Fi Rush l...
# 39  Positive  \n                                A week ago, ...
# 40  Positive  \n                                What a slap!...
# 41  Positive  \n                                Hi-Fi Rush e...
# 42  Positive  \n                                Even with it...
# 43  Positive  \n                                What you wil...
# 44  Positive  \n                                This is a wo...
# 45  Positive  \n                                Hi-Fi Rush a...
# 46  Positive  \n                                Hi-Fi Rush i...
# 47  Positive  \n                                Tango Gamewo...
# 48  Positive  \n                                Hi-Fi RUSH i...
# 49  Positive  \n                                A very welco...
# 50  Positive  \n                                Hi-Fi Rush i...
# 51     Mixed  \n                                For someone ...
# 52     Mixed  \n                                Settling int...
# 53     Mixed  \n                                Hi-Fi Rush i...
#
#                                             cleanText  \
# 0   what likely started out as an xbox and or beth...
# 1   it combines showstopping unique gameplay with ...
# 2   hi fi rush is a rock themed masterpiece rhythm...
# 3   i had a smile on my face from beginning to end...
# 4   there is nothing as addictive fun and well bui...
# 5   hi fi rush is a light hearted game about comra...
# 6   hi fi rush is a highly enjoyable action advent...
# 7   hi fi rush is a thrilling rhythm game that ooz...
# 8   it s been a long time since a game has conquer...
# 9   hi fi rush is going to stay with me i absolute...
# 10  hi fi rush came out of nowhere and floored me ...
# 11  this is an impeccable platform and action titl...
# 12  everything comes together wonderfully with the...
# 13  hi fi rush nails pretty much every aspect of i...
# 14  after a lackluster line up in 2022 microsoft i...
# 15  hi fi rush delivers energizing gameplay that i...
# 16  hi fi rush is a wonderful reminder of why we p...
# 17  hi fi rush is an utterly beguiling new take on...
# 18  i can t imagine any of hi fi rush getting old ...
# 19  from beginning to end hi fi rush is a rhythmic...
# 20  tango gameworks has done it once again hi fi r...
# 21  hi fi rush will make us feel that we are enjoy...
# 22  despite these missteps hi fi rush is a tremend...
# 23  hi fi rush is a rhythmic adventure full of act...
# 24  best of all the execution is perfect delightin...
# 25  hi fi rush is an amazing rhythmic and action g...
# 26  hi fi rush is not only a great surprise for th...
# 27  hi fi rush is a great little rock and roll gam...
# 28  even though it has flashes of games that came ...
# 29  hi fi rush is a surprise in every way launch g...
# 30  i simply have to salute bethesda and microsoft...
# 31  tango gameworks rhythm based actioner is not o...
# 32  hi fi rush is a gamble won hands down by tango...
# 33  hi fi rush cracks the rhythm action genre wide...
# 34  hi fi rush is a celebration of the videogame a...
# 35  there s an infectious easy going joy to this w...
# 36  hi fi rush mixes the intensity and complexity ...
# 37  hi fi rush is an energetic and frantic game wi...
# 38  hi fi rush lives up to the hype it has receive...
# 39  a week ago we didn t know that something like ...
# 40  what a slap with this luminous shadow drop sol...
# 41  hi fi rush excellently blends the action and r...
# 42  even with its few distracting flaws almost any...
# 43  what you will remember about hi fi rush is jus...
# 44  this is a world that robot assassins aside is ...
# 45  hi fi rush arrived by surprise unassumingly wi...
# 46  hi fi rush is a charming action game with a gr...
# 47  tango gameworks breaks from expectation to rel...
# 48  hi fi rush is an absolute delight a simple ide...
# 49  a very welcome surprise that is one of the mos...
# 50  hi fi rush is oozing with style and confidence...
# 51  for someone who also works in music journalism...
# 52  settling into hi fi rush s groove might requir...
# 53  hi fi rush is a nice surprise from tango gamew...
#
#                                             finalText  \
# 0   likely started xbox bethesda executive thinkin...
# 1   combines showstopping unique gameplay best cel...
# 2   hi fi rush rock themed masterpiece rhythm acti...
# 3   smile face beginning end playing hi fi rush co...
# 4   nothing addictive fun well built hi fi rush xb...
# 5   hi fi rush light hearted game comradery taking...
# 6   hi fi rush highly enjoyable action adventure f...
# 7   hi fi rush thrilling rhythm game oozes style s...
# 8   long time since game conquered us like hi fi r...
# 9   hi fi rush going stay absolutely adore game fa...
# 10  hi fi rush came nowhere floored one favorite l...
# 11  impeccable platform action title bases gamepla...
# 12  everything comes together wonderfully combat p...
# 13  hi fi rush nails pretty much every aspect form...
# 14  lackluster line 2022 microsoft back business h...
# 15  hi fi rush delivers energizing gameplay smooth...
# 16  hi fi rush wonderful reminder play games first...
# 17  hi fi rush utterly beguiling new take rhythm a...
# 18  imagine hi fi rush getting old vibrant full li...
# 19  beginning end hi fi rush rhythmic thrill ride ...
# 20  tango gameworks done hi fi rush fantastic expe...
# 21  hi fi rush make us feel enjoying interactive a...
# 22  despite missteps hi fi rush tremendous game eq...
# 23  hi fi rush rhythmic adventure full action humo...
# 24  best execution perfect delighting us fresh uni...
# 25  hi fi rush amazing rhythmic action game feels ...
# 26  hi fi rush great surprise whole xbox audience ...
# 27  hi fi rush great little rock roll game one des...
# 28  even though flashes games came hi fi rush uniq...
# 29  hi fi rush surprise every way launch gameplay ...
# 30  simply salute bethesda microsoft first foremos...
# 31  tango gameworks rhythm based actioner one enjo...
# 32  hi fi rush gamble hands tango gameworks ventur...
# 33  hi fi rush cracks rhythm action genre wide ope...
# 34  hi fi rush celebration videogame perfect fusio...
# 35  infectious easy going joy whole adventure back...
# 36  hi fi rush mixes intensity complexity hack sla...
# 37  hi fi rush energetic frantic game lots charact...
# 38  hi fi rush lives hype received fun experience ...
# 39  week ago know something like going happen toda...
# 40  slap luminous shadow drop sold low price integ...
# 41  hi fi rush excellently blends action rhythm ga...
# 42  even distracting flaws almost anyone find some...
# 43  remember hi fi rush charming rare game one maj...
# 44  world robot assassins aside pleasurable exist ...
# 45  hi fi rush arrived surprise unassumingly witho...
# 46  hi fi rush charming action game great art styl...
# 47  tango gameworks breaks expectation release bol...
# 48  hi fi rush absolute delight simple idea could ...
# 49  welcome surprise one enjoyably unique games xb...
# 50  hi fi rush oozing style confidence like messy ...
# 51  someone also works music journalism skills sha...
# 52  settling hi fi rush groove might require recal...
# 53  hi fi rush nice surprise tango gameworks origi...
#
#                                           stemmedText  \
# 0   like start xbox bethesda execut think hey neat...
# 1   combin showstop uniqu gameplay best cel shade ...
# 2   hi fi rush rock theme masterpiec rhythm action...
# 3   smile face begin end play hi fi rush color gra...
# 4   noth addict fun well built hi fi rush xbox cat...
# 5   hi fi rush light heart game comraderi take cor...
# 6   hi fi rush high enjoy action adventur fuse sol...
# 7   hi fi rush thrill rhythm game ooz style substa...
# 8   long time sinc game conquer us like hi fi rush...
# 9   hi fi rush go stay absolut ador game far far w...
# 10  hi fi rush came nowher floor one favorit look ...
# 11  impecc platform action titl base gameplay rhyt...
# 12  everyth come togeth wonder combat platform mus...
# 13  hi fi rush nail pretti much everi aspect formu...
# 14  lacklust line 2022 microsoft back busi hi fi r...
# 15  hi fi rush deliv energ gameplay smoother slide...
# 16  hi fi rush wonder remind play game first place...
# 17  hi fi rush utter beguil new take rhythm action...
# 18  imagin hi fi rush get old vibrant full life un...
# 19  begin end hi fi rush rhythmic thrill ride repl...
# 20  tango gamework done hi fi rush fantast experi ...
# 21  hi fi rush make us feel enjoy interact anim sh...
# 22  despit misstep hi fi rush tremend game equal p...
# 23  hi fi rush rhythmic adventur full action humor...
# 24  best execut perfect delight us fresh uniqu ori...
# 25  hi fi rush amaz rhythmic action game feel uniq...
# 26  hi fi rush great surpris whole xbox audienc al...
# 27  hi fi rush great littl rock roll game one dese...
# 28  even though flash game came hi fi rush uniqu m...
# 29  hi fi rush surpris everi way launch gameplay s...
# 30  simpli salut bethesda microsoft first foremost...
# 31  tango gamework rhythm base action one enjoy ga...
# 32  hi fi rush gambl hand tango gamework ventur un...
# 33  hi fi rush crack rhythm action genr wide open ...
# 34  hi fi rush celebr videogam perfect fusion hack...
# 35  infecti easi go joy whole adventur back addict...
# 36  hi fi rush mix intens complex hack slash high ...
# 37  hi fi rush energet frantic game lot charact ch...
# 38  hi fi rush live hype receiv fun experi music b...
# 39  week ago know someth like go happen today hard...
# 40  slap lumin shadow drop sold low price integr g...
# 41  hi fi rush excel blend action rhythm game genr...
# 42  even distract flaw almost anyon find someth wo...
# 43  rememb hi fi rush charm rare game one major de...
# 44  world robot assassin asid pleasur exist within...
# 45  hi fi rush arriv surpris unassum without mani ...
# 46  hi fi rush charm action game great art style f...
# 47  tango gamework break expect releas bold rhythm...
# 48  hi fi rush absolut delight simpl idea could ex...
# 49  welcom surpris one enjoy uniqu game xbox one b...
# 50  hi fi rush ooz style confid like messi first a...
# 51  someon also work music journal skill shaki say...
# 52  settl hi fi rush groov might requir recalibr h...
# 53  hi fi rush nice surpris tango gamework origin ...
#
#                                        lemmatizedText
# 0   likely started xbox bethesda executive thinkin...
# 1   combine showstopping unique gameplay best cel ...
# 2   hi fi rush rock themed masterpiece rhythm acti...
# 3   smile face beginning end playing hi fi rush co...
# 4   nothing addictive fun well built hi fi rush xb...
# 5   hi fi rush light hearted game comradery taking...
# 6   hi fi rush highly enjoyable action adventure f...
# 7   hi fi rush thrilling rhythm game ooze style su...
# 8   long time since game conquered u like hi fi ru...
# 9   hi fi rush going stay absolutely adore game fa...
# 10  hi fi rush came nowhere floored one favorite l...
# 11  impeccable platform action title base gameplay...
# 12  everything come together wonderfully combat pl...
# 13  hi fi rush nail pretty much every aspect formu...
# 14  lackluster line 2022 microsoft back business h...
# 15  hi fi rush delivers energizing gameplay smooth...
# 16  hi fi rush wonderful reminder play game first ...
# 17  hi fi rush utterly beguiling new take rhythm a...
# 18  imagine hi fi rush getting old vibrant full li...
# 19  beginning end hi fi rush rhythmic thrill ride ...
# 20  tango gameworks done hi fi rush fantastic expe...
# 21  hi fi rush make u feel enjoying interactive an...
# 22  despite misstep hi fi rush tremendous game equ...
# 23  hi fi rush rhythmic adventure full action humo...
# 24  best execution perfect delighting u fresh uniq...
# 25  hi fi rush amazing rhythmic action game feel u...
# 26  hi fi rush great surprise whole xbox audience ...
# 27  hi fi rush great little rock roll game one des...
# 28  even though flash game came hi fi rush unique ...
# 29  hi fi rush surprise every way launch gameplay ...
# 30  simply salute bethesda microsoft first foremos...
# 31  tango gameworks rhythm based actioner one enjo...
# 32  hi fi rush gamble hand tango gameworks venturi...
# 33  hi fi rush crack rhythm action genre wide open...
# 34  hi fi rush celebration videogame perfect fusio...
# 35  infectious easy going joy whole adventure back...
# 36  hi fi rush mix intensity complexity hack slash...
# 37  hi fi rush energetic frantic game lot characte...
# 38  hi fi rush life hype received fun experience m...
# 39  week ago know something like going happen toda...
# 40  slap luminous shadow drop sold low price integ...
# 41  hi fi rush excellently blend action rhythm gam...
# 42  even distracting flaw almost anyone find somet...
# 43  remember hi fi rush charming rare game one maj...
# 44  world robot assassin aside pleasurable exist w...
# 45  hi fi rush arrived surprise unassumingly witho...
# 46  hi fi rush charming action game great art styl...
# 47  tango gameworks break expectation release bold...
# 48  hi fi rush absolute delight simple idea could ...
# 49  welcome surprise one enjoyably unique game xbo...
# 50  hi fi rush oozing style confidence like messy ...
# 51  someone also work music journalism skill shaky...
# 52  settling hi fi rush groove might require recal...
# 53  hi fi rush nice surprise tango gameworks origi...

# %% [markdown]
# ### Data storage
#
# Once we have cleaned the data, we will store it in order to use it in the future.

# %%
for game in games:
    for tipo in reviewTypes:
        reviews[tipo][game["name"]] = reviews[tipo][game["name"]].drop(['tokens', 'final', 'stemmed', 'lemmatized'], axis=1)

# %%
for game in games:
    for tipo in reviewTypes:
        path = f'Videojocs/cleanReviews/{tipo}_{game["name"]}.csv'
        reviews[tipo][game["name"]].to_csv(path, index=False)

# %% [markdown]
# ## Next notebook
#
# We have cleaned all the data that we want to analyze from all the noise and unnecessary information. However, we still don't know what are the main topics that are talked about in this texts. In order to discover it, we will perform [topic modelling](./05TopicModelling.ipynb) along the following notebook.
